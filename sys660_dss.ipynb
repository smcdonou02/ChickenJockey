# %%
#Justin Baumann & Colin Mcdermott
"""
Informatics & Software Development
Final Project Code
Author: Justin Baumann & Colin Mcdermott
Date: 12/10/2022
"""
# Out:
# '\nInformatics & Software Development\nFinal Project Code\nAuthor: Justin Baumann & Colin Mcdermott\nDate: 12/10/2022\n'

# %%
# import pandas as pd
# import ast
# import ipywidgets as widgets
# from IPython.display import display, clear_output

# # Load your data
# df = pd.read_csv('/data/main_colleges_data.csv', low_memory=False)

# # Parse the bachelor_degrees column if present
# if 'bachelor_degrees' in df.columns:
#     df['bachelor_degrees'] = df['bachelor_degrees'].apply(
#         lambda x: ast.literal_eval(x) if pd.notnull(x) else {}
#     )

# def get_all_majors(df):
#     majors = set()
#     for d in df['bachelor_degrees'].dropna():
#         majors.update(d.keys())
#     return sorted(majors)

# # Widgets with empty descriptions for sliders
# state_label = widgets.Label('State:')
# state_widget = widgets.Dropdown(
#     options=[''] + sorted(df['state_code'].dropna().unique().tolist()),
#     description='',
#     layout=widgets.Layout(width='250px')
# )

# city_label = widgets.Label('City (optional):')
# city_widget = widgets.Text(
#     value='',
#     description='',
#     layout=widgets.Layout(width='250px')
# )

# max_tuition_label = widgets.Label('Max Tuition ($):')
# max_tuition_widget = widgets.IntSlider(
#     value=60000,
#     min=0,
#     max=100000,
#     step=1000,
#     description='',
#     continuous_update=False,
#     layout=widgets.Layout(width='250px')
# )

# min_acceptance_label = widgets.Label('Min Acceptance Rate (%):')
# min_acceptance_widget = widgets.FloatSlider(
#     value=0,
#     min=0,
#     max=100,
#     step=0.1,
#     description='',
#     continuous_update=False,
#     layout=widgets.Layout(width='250px')
# )

# min_earnings_label = widgets.Label('Min Median Earnings ($):')
# min_earnings_widget = widgets.IntSlider(
#     value=10000,
#     min=0,
#     max=200000,
#     step=1000,
#     description='',
#     continuous_update=False,
#     layout=widgets.Layout(width='250px')
# )

# major_label = widgets.Label('Major:')
# major_widget = widgets.Dropdown(
#     options=[''] + get_all_majors(df),
#     description='',
#     layout=widgets.Layout(width='250px')
# )

# min_major_students_label = widgets.Label('Min Students in Major:')
# min_major_students_widget = widgets.IntSlider(
#     value=0,
#     min=0,
#     max=1000,
#     step=10,
#     description='',
#     continuous_update=False,
#     layout=widgets.Layout(width='250px')
# )

# def filter_colleges(state, city, max_tuition, min_acceptance, min_earnings, major, min_major_students):
#     filtered = df.copy()
#     if state:
#         filtered = filtered[filtered['state_code'] == state]
#     if city:
#         filtered = filtered[filtered['city'].str.contains(city, case=False, na=False)]
#     if 'tuition_and_fees' in filtered.columns:
#         filtered = filtered[filtered['tuition_and_fees'] <= max_tuition]
#     if 'acceptance_rate' in filtered.columns:
#         filtered = filtered[filtered['acceptance_rate'] >= min_acceptance]
#     if 'median_alumni_earnings' in filtered.columns:
#         filtered = filtered[filtered['median_alumni_earnings'] >= min_earnings]
#     if major and 'bachelor_degrees' in filtered.columns:
#         def has_major(majors_dict):
#             try:
#                 return majors_dict.get(major, {}).get('total', 0) >= min_major_students
#             except Exception:
#                 return False
#         filtered = filtered[filtered['bachelor_degrees'].apply(has_major)]
#     display(filtered.head(20))  # Show first 20 results

# # Arrange labels and widgets in HBoxes
# ui = widgets.VBox([
#     widgets.HBox([state_label, state_widget]),
#     widgets.HBox([city_label, city_widget]),
#     widgets.HBox([max_tuition_label, max_tuition_widget]),
#     widgets.HBox([min_acceptance_label, min_acceptance_widget]),
#     widgets.HBox([min_earnings_label, min_earnings_widget]),
#     widgets.HBox([major_label, major_widget]),
#     widgets.HBox([min_major_students_label, min_major_students_widget])
# ])

# out = widgets.Output()

# def on_change(change):
#     with out:
#         clear_output(wait=True)
#         filter_colleges(
#             state_widget.value,
#             city_widget.value,
#             max_tuition_widget.value,
#             min_acceptance_widget.value,
#             min_earnings_widget.value,
#             major_widget.value,
#             min_major_students_widget.value
#         )

# for w in [state_widget, city_widget, max_tuition_widget, min_acceptance_widget, min_earnings_widget, major_widget, min_major_students_widget]:
#     w.observe(on_change, names='value')

# display(ui, out)
# on_change(None)  # Initial display

# %%
# import pandas as pd

# # Load the data
# main_colleges_data = pd.read_csv('main_colleges_data.csv', dtype=str)
# access = pd.read_csv('UniversityDashboard-Table2-Accessibility.csv', dtype=str)

# # Prepare for matching: strip and uppercase for robust matching
# main_colleges_data['University_clean'] = main_colleges_data['instnm'].str.strip().str.upper()
# access['University_clean'] = access['University'].str.strip().str.upper()

# # Merge the accessibility score into the main dataframe
# main_colleges_data = main_colleges_data.merge(
#     access[['University_clean', 'Accessibility Total (20 points)']],
#     on='University_clean',
#     how='left'
# )

# # Optionally, drop the helper column
# main_colleges_data.drop(columns=['University_clean'], inplace=True)

# # Save or use the updated DataFrame
# main_colleges_data.to_csv('main_colleges_data_with_accessibility.csv', index=False)

# %%
# import pandas as pd
# import ast
# import ipywidgets as widgets
# from IPython.display import display, clear_output

# # Load your data
# df = pd.read_csv('main_colleges_data.csv', low_memory=False)

# # Parse the bachelor_degrees column if present
# if 'bachelor_degrees' in df.columns:
#     df['bachelor_degrees'] = df['bachelor_degrees'].apply(
#         lambda x: ast.literal_eval(x) if pd.notnull(x) else {}
#     )

# def get_all_majors(df):
#     majors = set()
#     for d in df['bachelor_degrees'].dropna():
#         majors.update(d.keys())
#     return sorted(majors)

# # Multi-select for states
# state_label = widgets.Label('States:')
# state_widget = widgets.SelectMultiple(
#     options=sorted(df['state_code'].dropna().unique().tolist()),
#     value=[],
#     description='',
#     layout=widgets.Layout(width='250px', height='100px')
# )

# # Multi-select for majors
# major_label = widgets.Label('Majors:')
# major_widget = widgets.SelectMultiple(
#     options=get_all_majors(df),
#     value=[],
#     description='',
#     layout=widgets.Layout(width='250px', height='100px')
# )

# city_label = widgets.Label('City (optional):')
# city_widget = widgets.Text(
#     value='',
#     description='',
#     layout=widgets.Layout(width='250px')
# )

# max_tuition_label = widgets.Label('Max Tuition ($):')
# max_tuition_widget = widgets.IntSlider(
#     value=60000,
#     min=0,
#     max=100000,
#     step=1000,
#     description='',
#     continuous_update=False,
#     layout=widgets.Layout(width='250px')
# )

# min_acceptance_label = widgets.Label('Min Acceptance Rate (%):')
# min_acceptance_widget = widgets.FloatSlider(
#     value=0,
#     min=0,
#     max=100,
#     step=0.1,
#     description='',
#     continuous_update=False,
#     layout=widgets.Layout(width='250px')
# )

# min_earnings_label = widgets.Label('Min Median Earnings ($):')
# min_earnings_widget = widgets.IntSlider(
#     value=10000,
#     min=0,
#     max=200000,
#     step=1000,
#     description='',
#     continuous_update=False,
#     layout=widgets.Layout(width='250px')
# )

# min_major_students_label = widgets.Label('Min Students in Major:')
# min_major_students_widget = widgets.IntSlider(
#     value=0,
#     min=0,
#     max=1000,
#     step=10,
#     description='',
#     continuous_update=False,
#     layout=widgets.Layout(width='250px')
# )

# def filter_colleges(states, city, max_tuition, min_acceptance, min_earnings, majors, min_major_students):
#     filtered = df.copy()
#     if states:
#         filtered = filtered[filtered['state_code'].isin(states)]
#     if city:
#         filtered = filtered[filtered['city'].str.contains(city, case=False, na=False)]
#     if 'tuition_and_fees' in filtered.columns:
#         filtered = filtered[filtered['tuition_and_fees'] <= max_tuition]
#     if 'acceptance_rate' in filtered.columns:
#         filtered = filtered[filtered['acceptance_rate'] >= min_acceptance]
#     if 'median_alumni_earnings' in filtered.columns:
#         filtered = filtered[filtered['median_alumni_earnings'] >= min_earnings]
#     if majors and 'bachelor_degrees' in filtered.columns:
#         def has_any_major(majors_dict):
#             try:
#                 return any(majors_dict.get(major, {}).get('total', 0) >= min_major_students for major in majors)
#             except Exception:
#                 return False
#         filtered = filtered[filtered['bachelor_degrees'].apply(has_any_major)]
#     display(filtered.head(20))  # Show first 20 results

# # Arrange labels and widgets in HBoxes
# ui = widgets.VBox([
#     widgets.HBox([state_label, state_widget]),
#     widgets.HBox([city_label, city_widget]),
#     widgets.HBox([max_tuition_label, max_tuition_widget]),
#     widgets.HBox([min_acceptance_label, min_acceptance_widget]),
#     widgets.HBox([min_earnings_label, min_earnings_widget]),
#     widgets.HBox([major_label, major_widget]),
#     widgets.HBox([min_major_students_label, min_major_students_widget])
# ])

# out = widgets.Output()

# def on_change(change):
#     with out:
#         clear_output(wait=True)
#         filter_colleges(
#             list(state_widget.value),
#             city_widget.value,
#             max_tuition_widget.value,
#             min_acceptance_widget.value,
#             min_earnings_widget.value,
#             list(major_widget.value),
#             min_major_students_widget.value
#         )

# for w in [state_widget, city_widget, max_tuition_widget, min_acceptance_widget, min_earnings_widget, major_widget, min_major_students_widget]:
#     w.observe(on_change, names='value')

# display(ui, out)
# on_change(None)  # Initial display
# Out:
# ...
# Output()

# %%
import pandas as pd
import ast
import ipywidgets as widgets
from IPython.display import display, clear_output
from sklearn.preprocessing import MinMaxScaler

# Load and prepare data
df = pd.read_csv('main_colleges_data.csv', low_memory=False)

if 'bachelor_degrees' in df.columns:
    df['bachelor_degrees'] = df['bachelor_degrees'].apply(
        lambda x: ast.literal_eval(x) if pd.notnull(x) else {}
    )

def get_all_majors(df):
    majors = set()
    for d in df['bachelor_degrees'].dropna():
        majors.update(d.keys())
    return sorted(majors)

# Widgets for filters
state_widget = widgets.SelectMultiple(
    options=sorted(df['state_code'].dropna().unique().tolist()),
    value=[],
    description='Select State(s):',
    layout=widgets.Layout(width='300px', height='120px')
)

city_widget = widgets.Text(
    value='',
    description='City (optional):',
    layout=widgets.Layout(width='300px')
)

major_widget = widgets.SelectMultiple(
    options=get_all_majors(df),
    value=[],
    description='Select Major(s):',
    layout=widgets.Layout(width='300px', height='120px')
)

min_major_students_widget = widgets.IntSlider(
    value=10,
    min=0,
    max=1000,
    step=10,
    description='Min Students in Major:',
    continuous_update=False,
    layout=widgets.Layout(width='300px')
)

max_tuition_widget = widgets.IntSlider(
    value=60000,
    min=0,
    max=100000,
    step=1000,
    description='Max Tuition ($):',
    continuous_update=False,
    layout=widgets.Layout(width='300px')
)

min_acceptance_widget = widgets.FloatSlider(
    value=0,
    min=0,
    max=100,
    step=0.1,
    description='Min Acceptance Rate (%):',
    continuous_update=False,
    layout=widgets.Layout(width='300px')
)

min_earnings_widget = widgets.IntSlider(
    value=10000,
    min=0,
    max=200000,
    step=1000,
    description='Min Median Earnings ($):',
    continuous_update=False,
    layout=widgets.Layout(width='300px')
)

# Criteria weights
tuition_weight = widgets.FloatSlider(
    value=5, min=0, max=10, step=0.5,
    description='Tuition Importance:',
    continuous_update=False,
    layout=widgets.Layout(width='300px')
)

acceptance_weight = widgets.FloatSlider(
    value=5, min=0, max=10, step=0.5,
    description='Acceptance Rate Importance:',
    continuous_update=False,
    layout=widgets.Layout(width='300px')
)

earnings_weight = widgets.FloatSlider(
    value=5, min=0, max=10, step=0.5,
    description='Earnings Importance:',
    continuous_update=False,
    layout=widgets.Layout(width='300px')
)

major_weight = widgets.FloatSlider(
    value=5, min=0, max=10, step=0.5,
    description='Major Match Importance:',
    continuous_update=False,
    layout=widgets.Layout(width='300px')
)

# Scoring function
def calculate_recommendation_scores(filtered_df, weights, selected_majors, min_major_students):
    scaler = MinMaxScaler()
    # Normalize weights
    total_weight = sum(weights.values())
    if total_weight == 0:
        normalized_weights = {k: 1/4 for k in weights}
    else:
        normalized_weights = {k: v/total_weight for k, v in weights.items()}
    
    # Build scoring matrix
    matrix = filtered_df[['tuition_and_fees', 'acceptance_rate', 'median_alumni_earnings']].copy()
    
    # Major match: 1 if any selected major meets min students, else 0
    def major_match(majors_dict):
        if not selected_majors:
            return 1  # If no majors selected, don't penalize
        try:
            return int(any(
                majors_dict.get(major, {}).get('total', 0) >= min_major_students
                for major in selected_majors
            ))
        except Exception:
            return 0
    matrix['major_score'] = filtered_df['bachelor_degrees'].apply(major_match)
    
    # Normalize features
    for col, norm_col, invert in [
        ('tuition_and_fees', 'tuition_norm', True),
        ('acceptance_rate', 'acceptance_norm', False),
        ('median_alumni_earnings', 'earnings_norm', False)
    ]:
        if col in matrix.columns and matrix[col].notna().sum() > 1:
            norm = scaler.fit_transform(matrix[[col]].fillna(matrix[col].mean()))
            if invert:
                norm = 1 - norm  # Lower tuition is better
            matrix[norm_col] = norm.flatten()
        else:
            matrix[norm_col] = 1.0
    
    # Weighted sum
    matrix['score'] = (
        matrix['tuition_norm'] * normalized_weights['tuition'] +
        matrix['acceptance_norm'] * normalized_weights['acceptance'] +
        matrix['earnings_norm'] * normalized_weights['earnings'] +
        matrix['major_score'] * normalized_weights['major']
    )
    return matrix['score']

def update_recommendations(change):
    with out:
        clear_output(wait=True)
        filtered = df.copy()
        # State filter
        if state_widget.value:
            filtered = filtered[filtered['state_code'].isin(state_widget.value)]
        # City filter
        if city_widget.value:
            filtered = filtered[filtered['city'].str.contains(city_widget.value, case=False, na=False)]
        # Tuition
        if 'tuition_and_fees' in filtered.columns:
            filtered = filtered[filtered['tuition_and_fees'] <= max_tuition_widget.value]
        # Acceptance rate
        if 'acceptance_rate' in filtered.columns:
            filtered = filtered[filtered['acceptance_rate'] >= min_acceptance_widget.value]
        # Earnings
        if 'median_alumni_earnings' in filtered.columns:
            filtered = filtered[filtered['median_alumni_earnings'] >= min_earnings_widget.value]
        # Major filter (at least one selected major meets min students)
        selected_majors = list(major_widget.value)
        min_major_students = min_major_students_widget.value
        if selected_majors and 'bachelor_degrees' in filtered.columns:
            def has_any_major(majors_dict):
                try:
                    return any(majors_dict.get(major, {}).get('total', 0) >= min_major_students for major in selected_majors)
                except Exception:
                    return False
            filtered = filtered[filtered['bachelor_degrees'].apply(has_any_major)]
        # If nothing matches, display message
        if filtered.empty:
            display(pd.DataFrame({"Message": ["No colleges match your criteria."]}))
            return
        # Calculate scores
        weights = {
            'tuition': tuition_weight.value,
            'acceptance': acceptance_weight.value,
            'earnings': earnings_weight.value,
            'major': major_weight.value
        }
        filtered = filtered.copy()
        filtered['recommendation_score'] = calculate_recommendation_scores(
            filtered, weights, selected_majors, min_major_students
        )
        filtered = filtered.sort_values('recommendation_score', ascending=False)
        display_cols = [
            'instnm', 'city', 'state_code', 'recommendation_score',
            'tuition_and_fees', 'acceptance_rate', 'median_alumni_earnings'
        ]
        filtered['recommendation_score'] = filtered['recommendation_score'].round(4)
        display(filtered[display_cols].head(20).style.format({
            'recommendation_score': '{:.4f}',
            'tuition_and_fees': '${:,.0f}',
            'acceptance_rate': '{:.1f}%',
            'median_alumni_earnings': '${:,.0f}'
        }))

# UI Layout
filters = widgets.VBox([
    widgets.HTML('<h3>Filter Criteria</h3>'),
    state_widget,
    city_widget,
    major_widget,
    min_major_students_widget,
    max_tuition_widget,
    min_acceptance_widget,
    min_earnings_widget
])

weights = widgets.VBox([
    widgets.HTML('<h3>Criteria Importance (0-10)</h3>'),
    tuition_weight,
    acceptance_weight,
    earnings_weight,
    major_weight
])

ui = widgets.Tab(children=[filters, weights])
ui.set_title(0, 'Filters')
ui.set_title(1, 'Scoring Weights')

out = widgets.Output()

for w in [
    state_widget, city_widget, major_widget, min_major_students_widget,
    max_tuition_widget, min_acceptance_widget, min_earnings_widget,
    tuition_weight, acceptance_weight, earnings_weight, major_weight
]:
    w.observe(update_recommendations, names='value')

display(ui, out)
update_recommendations(None)
# Out:
# ...
# Output()
